# %% [markdown]
# ## Exploratory Data Analysis on YouTube data

# %% [markdown]
# ### 1. Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top 5
# ### and bottom 5 records.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv("youtube_dislike_dataset.csv")
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
df.head() # head() function retrieves the top five rows based on position.By default 5.
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
df.tail() # tail() function retrieves the bottom five rows based on position.By default 5.
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %% [markdown]
# ### 2. Check the info of the dataframe and write your inferences on data types and shape of the dataset.

# %%
df.info() #info() provides information about a dataframe.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %%
df.dtypes # return dtypes in the dataframe.
# Out:
# video_id         object
# title            object
# channel_id       object
# channel_title    object
# published_at     object
# view_count        int64
# likes             int64
# dislikes          int64
# comment_count     int64
# tags             object
# description      object
# comments         object
# dtype: object

# %%
df.shape #gives dimensionality of the dataframe.
# Out:
# (37422, 12)

# %% [markdown]
# ```INFERENCE :-```

# %% [markdown]
# ```
# The dataframe consists of 37422 rows and 12 columns.The following columns are video_id, title, channel_id, channel_title, published_at,view_count, likes, dislikes, comment_count, tags,description,published_month.The info() function tells us that the int64 datatype has 4 columns and object datatype has 8 columns.We can observe that the comments column has missing values in it.
#
# ```

# %% [markdown]
# ### 3. Check for the Percentage of the missing values and drop or impute them.

# %%
df.isnull().sum()
# Out:
# video_id           0
# title              0
# channel_id         0
# channel_title      0
# published_at       0
# view_count         0
# likes              0
# dislikes           0
# comment_count      0
# tags               0
# description        0
# comments         158
# dtype: int64

# %%
(df.isnull().sum()/len(df))*100 #Percentage of missing values
# Out:
# video_id         0.000000
# title            0.000000
# channel_id       0.000000
# channel_title    0.000000
# published_at     0.000000
# view_count       0.000000
# likes            0.000000
# dislikes         0.000000
# comment_count    0.000000
# tags             0.000000
# description      0.000000
# comments         0.422212
# dtype: float64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# video_id         0
# title            0
# channel_id       0
# channel_title    0
# published_at     0
# view_count       0
# likes            0
# dislikes         0
# comment_count    0
# tags             0
# description      0
# comments         0
# dtype: int64

# %% [markdown]
# ```
# Here the comments column has missing values.so 42.22 percentage missing values in it so it needs to be dropped.
# As you observed that none of the columns have missing values in it so comments column has been dropped from dataframe.
# ```

# %% [markdown]
# ### 4. Check the statistical summary of both numerical and categorical columns and write your inferences.

# %%
df.describe(exclude="object")# Statistical summary of numerical columns
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.726400e+04  3.726400e+04  3.726400e+04   3.726400e+04
# mean   5.710821e+06  1.672867e+05  4.996434e+03   9.966953e+03
# std    2.431304e+07  5.384931e+05  3.075194e+04   1.173465e+05
# min    2.036800e+04  2.200000e+01  3.000000e+00   1.000000e+00
# 25%    5.141305e+05  1.331725e+04  2.827500e+02   9.140000e+02
# 50%    1.321860e+06  4.255600e+04  7.980000e+02   2.347000e+03
# 75%    3.674527e+06  1.309665e+05  2.466250e+03   6.212000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %%
df.describe(include="object") # Statistical summary of categorical columns
# Out:
#            video_id  title                channel_id        channel_title  \
# count         37264  37264                     37264                37264
# unique        37264  36958                     10891                10813
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
#
#                published_at   tags description  \
# count                 37264  37264       37264
# unique                36617  28705       35479
# top     2020-10-16 04:00:10
# freq                      6   3808         587
#
#                                                  comments
# count                                               37264
# unique                                              37264
# top     Respect to Dortmund fans,must be sad losing hi...
# freq                                                    1

# %% [markdown]
# ``` INFERENCE:- ```

# %% [markdown]
# ```
# The statistical summary of numerical columns are view_count,likes,dislikes,comments_count. The statistical summary of categorical columns are video_id,title,channel_id,channel_title,published_at,tags and description.The video_id has 37264 unique count.The title has 36958 unique count.The channel_id has 10891 unique count.The channel_title has 10813 unique count.The published_at has 36617 unique count.The tags has 28705 unique count.The description has 35479 unique rows.So all the rows in categorical has 37264.The maximum for numerical summary are dislikes column.
# ```

# %% [markdown]
# ### 5. Convert datatype of column published_at from object to pandas datetime.

# %%
df['published_at']=pd.to_datetime(df['published_at']) # converting published_at column to datetime

# %%
df.dtypes
# Out:
# video_id                 object
# title                    object
# channel_id               object
# channel_title            object
# published_at     datetime64[ns]
# view_count                int64
# likes                     int64
# dislikes                  int64
# comment_count             int64
# tags                     object
# description              object
# comments                 object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37264 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37264 non-null  object
#  1   title          37264 non-null  object
#  2   channel_id     37264 non-null  object
#  3   channel_title  37264 non-null  object
#  4   published_at   37264 non-null  datetime64[ns]
#  5   view_count     37264 non-null  int64
#  6   likes          37264 non-null  int64
#  7   dislikes       37264 non-null  int64
#  8   comment_count  37264 non-null  int64
#  9   tags           37264 non-null  object
#  10  description    37264 non-null  object
#  11  comments       37264 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(7)
# memory usage: 3.7+ MB

# %% [markdown]
# ### 6. Create a new column as 'published_month' using the column published_at (display the months only)

# %%
df['published_at']
# Out:
# 0       2021-07-01 10:00:00
# 1       2021-06-10 16:00:00
# 2       2021-09-20 01:03:32
# 3       2021-03-03 10:00:17
# 4       2021-12-07 13:00:00
#                 ...
# 37417   2021-02-12 05:03:49
# 37418   2021-01-16 05:39:05
# 37419   2021-06-02 09:00:10
# 37420   2020-10-20 20:59:30
# 37421   2021-05-23 21:00:31
# Name: published_at, Length: 37264, dtype: datetime64[ns]

# %%
df['published_month']=df['published_at'].dt.month #created a new column 'published_month'

# %%
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# ### 7. Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb' and so on.....

# %%
df['published_month'].replace({1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'Jun',7:'Jul',8:'Aug',
                              9:'Sep',10:'Oct',11:'Nov',12:'Dec'},inplace=True)

# %%
df['published_month'].to_frame()
# Out:
#       published_month
# 0                 Jul
# 1                 Jun
# 2                 Sep
# 3                 Mar
# 4                 Dec
# ...               ...
# 37417             Feb
# 37418             Jan
# 37419             Jun
# 37420             Oct
# 37421             May
#
# [37264 rows x 1 columns]

# %% [markdown]
# ### 8. Find the number of videos published each month and arrange the months in a decreasing order based on the video count.

# %%
month=df.groupby('published_month')['video_id'].count().sort_values(ascending=False)
print(month)
# Out:
# published_month
# Oct    4976
# Sep    4854
# Nov    4821
# Aug    4250
# Dec    3063
# Jul    2331
# Jun    2305
# Mar    2248
# Feb    2125
# Apr    2119
# Jan    2099
# May    2073
# Name: video_id, dtype: int64

# %%
pd.pivot_table(df,index='published_month',values='video_id',aggfunc='count').sort_values('video_id',ascending=False)
# Out:
#                  video_id
# published_month
# Oct                  4976
# Sep                  4854
# Nov                  4821
# Aug                  4250
# Dec                  3063
# Jul                  2331
# Jun                  2305
# Mar                  2248
# Feb                  2125
# Apr                  2119
# Jan                  2099
# May                  2073

# %% [markdown]
# ### 9. Find the count of unique video_id, channel_id and channel_title.

# %%
video_id_unique_count=df['video_id'].nunique() # nunique() counts number of distinct elements 
channel_id_unique_count=df['channel_id'].nunique()
channel_title_unique_count=df['channel_title'].nunique() 
print('The count of unique video_id is:',video_id_unique_count)
print('The count of unique channel_id is:',channel_id_unique_count)
print('The count of unique channel_title is:',channel_title_unique_count)
# Out:
# The count of unique video_id is: 37264
# The count of unique channel_id is: 10891
# The count of unique channel_title is: 10813

# %% [markdown]
# ### 10. Find the top10 channel names having the highest number of videos in the dataset and the bottom10having lowest number of videos.

# %% [markdown]
# ## TOP 10

# %%
df.groupby(by="channel_title")['video_id'].count().sort_values(ascending=False).head(10).to_frame() # top 10
# Out:
#                      video_id
# channel_title
# Sky Sports Football       533
# The United Stand          301
# BT Sport                  246
# NBA                       209
# NFL                       162
# WWE                       122
# SSSniperWolf               99
# SSundee                    98
# FORMULA 1                  87
# NHL                        86

# %%
pd.pivot_table(df,index="channel_title",values='video_id',aggfunc="count").sort_values(by='video_id',ascending=False).head(10) # top 10
# Out:
#                      video_id
# channel_title
# Sky Sports Football       533
# The United Stand          301
# BT Sport                  246
# NBA                       209
# NFL                       162
# WWE                       122
# SSSniperWolf               99
# SSundee                    98
# FORMULA 1                  87
# NHL                        86

# %% [markdown]
# ## BOTTOM 10

# %%
df.groupby(by="channel_title")['video_id'].count().sort_values(ascending=False).tail(10).to_frame() # bottom 10
# Out:
#                  video_id
# channel_title
# Karikku Tuned           1
# Karen Bustillos         1
# Karen Aslanyan          1
# Karchez                 1
# Karate Combat           1
# Kaptain Kuba            1
# Kanye West              1
# Kannur kitchen          1
# Kannada Cinema          1
# zoom                    1

# %%
pd.pivot_table(df,index="channel_title",values='video_id',aggfunc="count").sort_values(by='video_id',ascending=False).tail(10) # bottom 10
# Out:
#                  video_id
# channel_title
# Karikku Tuned           1
# Karen Bustillos         1
# Karen Aslanyan          1
# Karchez                 1
# Karate Combat           1
# Kaptain Kuba            1
# Kanye West              1
# Kannur kitchen          1
# Kannada Cinema          1
# zoom                    1

# %% [markdown]
# ### 11. Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences.

# %%
df.groupby('title')['likes'].sum().sort_values(ascending=False).to_frame().head(1) #maximum number of likes
# Out:
#                                   likes
# title
# BTS () 'Dynamite' Official MV  31837675

# %%
df.groupby('title')['likes'].sum().sort_values(ascending=True).to_frame().head(1) #minimum number of likes
# Out:
#                                likes
# title
# Leading the Charge | Circle K     22

# %% [markdown]
# ```INFERENCE:-```

# %% [markdown]
# ```
# The maximum number of likes for the title is BTS () 'Dynamite' Official MV (likes:-31837675).
# The minimum number of likes for the title is Leading the Charge | Circle K (likes:-22).
# ```

# %% [markdown]
# ### 12.  Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences.

# %%
df.groupby('title')['dislikes'].sum().sort_values(ascending=False).to_frame().head(1) # maximum number of dislikes
# Out:
#                                      dislikes
# title
# Cuties | Official Trailer | Netflix   2397733

# %%
df.groupby('title')['dislikes'].sum().sort_values(ascending=True).to_frame().head(1) # minimum number of dislikes
# Out:
#                                         dislikes
# title
# Tims For Good: A Taste Of The Familiar         3

# %% [markdown]
# ```INFERENCE:-```

# %% [markdown]
# ```
# The maximum number of dislikes for the title is Cuties | Official Trailer | Netflix (dislikes:2397733)
# The minimum number of dislikes for the title is Tims For Good: A Taste Of The Familiar (dislikes:3)
# ```

# %% [markdown]
# ### 13. Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot.

# %%
df[['view_count','dislikes']].corr()
# Out:
#             view_count  dislikes
# view_count    1.000000  0.684576
# dislikes      0.684576  1.000000

# %%
plt.scatter(df['view_count'],df['dislikes'])
plt.title('scatter plot view_count VS dislikes')
plt.xlabel('view_count')
plt.ylabel('dislikes')
plt.show()

# %% [markdown]
# ```INFERENCE:-```

# %% [markdown]
# ```
# From the graph,we can conclude that the a positive relationship between each other.If one variable increases,other variable also increases.From the correlation table, the correlation between view_count and dislikes is 0.684 so it is positive correlation between each other.
# ```

# %% [markdown]
# ### 14. Display all the information about the videos that were published in January, and mention the count of videos that were published in January.

# %%
jan_count=df[df['published_month']=='Jan']
jan_count
# Out:
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title        published_at  \
# ...

# %%
jan_count['video_id'].count()
# Out:
# 2099

# %%
jan_count.shape
# Out:
# (2099, 13)
